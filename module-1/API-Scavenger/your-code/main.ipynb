# %% [markdown]
# # API Scavenger Game
#
# ## Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp.

# %%
# import libraries here
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %% [markdown]
# Assuming the main lab repo is ironhack-datalabs/madrid-oct-2018, you will:
#
# #### 1. Obtain the full list of forks created from the main lab repo via Github API.

# %% [markdown]
# To list forks, we can use the GET method. As explained in the GitHub API documentation, we need to make the request to: GET /repos/:owner/:repo/forks.

# %%
token = '363abab909f45752e1ee3aaf446caf1834f63e7c'

# %%
# your code here
url='https://api.github.com/repos/ironhack-datalabs/dataV2-labs/forks?page=1&per_page=100'

response = requests.get(url, headers ={'Authorization' : 'token 363abab909f45752e1ee3aaf446caf1834f63e7c' })
results = response.json()
results
# Out:
# [{'id': 276714038,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNzY3MTQwMzg=',
#   'name': 'dataV2-labs',
#   'full_name': 'cmerticaru/dataV2-labs',
#   'private': False,
#   'owner': {'login': 'cmerticaru',
#    'id': 61248268,
#    'node_id': 'MDQ6VXNlcjYxMjQ4MjY4',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/61248268?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cmerticaru',
#    'html_url': 'https://github.com/cmerticaru',
#    'followers_url': 'https://api.github.com/users/cmerticaru/followers',
#    'following_url': 'https://api.github.com/users/cmerticaru/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/cmerticaru/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/cmerticaru/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/cmerticaru/subscriptions',
#    'organizations_url': 'https://api.github.com/users/cmerticaru/orgs',
# ...

# %% [markdown]
# #### 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
# Hint: Each language should appear only once in your array.
# Print the language array. It should be something like: ["Python", "Jupyter Notebook", "HTML"]

# %%
flattened_data = pd.json_normalize(results)
flattened_data
# Out:
#            id                           node_id         name  \
# 0   276714038  MDEwOlJlcG9zaXRvcnkyNzY3MTQwMzg=  dataV2-labs
# 1   274415901  MDEwOlJlcG9zaXRvcnkyNzQ0MTU5MDE=  dataV2-labs
# 2   274151443  MDEwOlJlcG9zaXRvcnkyNzQxNTE0NDM=  dataV2-labs
# 3   272914619  MDEwOlJlcG9zaXRvcnkyNzI5MTQ2MTk=  dataV2-labs
# 4   272536402  MDEwOlJlcG9zaXRvcnkyNzI1MzY0MDI=  dataV2-labs
# ..        ...                               ...          ...
# 95  224439437  MDEwOlJlcG9zaXRvcnkyMjQ0Mzk0Mzc=  dataV2-labs
# 96  223606324  MDEwOlJlcG9zaXRvcnkyMjM2MDYzMjQ=  dataV2-labs
# 97  223603944  MDEwOlJlcG9zaXRvcnkyMjM2MDM5NDQ=  dataV2-labs
# 98  223601191  MDEwOlJlcG9zaXRvcnkyMjM2MDExOTE=  dataV2-labs
# 99  222921424  MDEwOlJlcG9zaXRvcnkyMjI5MjE0MjQ=  dataV2-labs
#
#                        full_name  private  \
# 0         cmerticaru/dataV2-labs    False
# 1           aaronepv/dataV2-labs    False
# 2           Sanka101/dataV2-labs    False
# 3        Lucille-Art/dataV2-labs    False
# ...

# %%
# Your code

df=pd.DataFrame(flattened_data)
df
# Out:
#            id                           node_id         name  \
# 0   276714038  MDEwOlJlcG9zaXRvcnkyNzY3MTQwMzg=  dataV2-labs
# 1   274415901  MDEwOlJlcG9zaXRvcnkyNzQ0MTU5MDE=  dataV2-labs
# 2   274151443  MDEwOlJlcG9zaXRvcnkyNzQxNTE0NDM=  dataV2-labs
# 3   272914619  MDEwOlJlcG9zaXRvcnkyNzI5MTQ2MTk=  dataV2-labs
# 4   272536402  MDEwOlJlcG9zaXRvcnkyNzI1MzY0MDI=  dataV2-labs
# ..        ...                               ...          ...
# 95  224439437  MDEwOlJlcG9zaXRvcnkyMjQ0Mzk0Mzc=  dataV2-labs
# 96  223606324  MDEwOlJlcG9zaXRvcnkyMjM2MDYzMjQ=  dataV2-labs
# 97  223603944  MDEwOlJlcG9zaXRvcnkyMjM2MDM5NDQ=  dataV2-labs
# 98  223601191  MDEwOlJlcG9zaXRvcnkyMjM2MDExOTE=  dataV2-labs
# 99  222921424  MDEwOlJlcG9zaXRvcnkyMjI5MjE0MjQ=  dataV2-labs
#
#                        full_name  private  \
# 0         cmerticaru/dataV2-labs    False
# 1           aaronepv/dataV2-labs    False
# 2           Sanka101/dataV2-labs    False
# 3        Lucille-Art/dataV2-labs    False
# ...

# %%
# your code here
df['language']
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
#       ...
# 95    None
# 96    None
# 97    None
# 98    None
# 99    None
# Name: language, Length: 100, dtype: object

# %%
df.language.value_counts()
# Out:
# Jupyter Notebook    51
# AGS Script           1
# Name: language, dtype: int64

# %% [markdown]
# ## Challenge 2: Count Commits
# Count how many commits were made in the month of october of 2018.
# #### 1. Obtain all the commits made in October 2018 via API, which is a JSON array that contains multiple commit objects.

# %%
# your code here

commits = df[df["pushed_at"]> "2018-10-01T00:00:00Z"]
commits
# Out:
#            id                           node_id         name  \
# 0   276714038  MDEwOlJlcG9zaXRvcnkyNzY3MTQwMzg=  dataV2-labs
# 1   274415901  MDEwOlJlcG9zaXRvcnkyNzQ0MTU5MDE=  dataV2-labs
# 2   274151443  MDEwOlJlcG9zaXRvcnkyNzQxNTE0NDM=  dataV2-labs
# 3   272914619  MDEwOlJlcG9zaXRvcnkyNzI5MTQ2MTk=  dataV2-labs
# 4   272536402  MDEwOlJlcG9zaXRvcnkyNzI1MzY0MDI=  dataV2-labs
# ..        ...                               ...          ...
# 95  224439437  MDEwOlJlcG9zaXRvcnkyMjQ0Mzk0Mzc=  dataV2-labs
# 96  223606324  MDEwOlJlcG9zaXRvcnkyMjM2MDYzMjQ=  dataV2-labs
# 97  223603944  MDEwOlJlcG9zaXRvcnkyMjM2MDM5NDQ=  dataV2-labs
# 98  223601191  MDEwOlJlcG9zaXRvcnkyMjM2MDExOTE=  dataV2-labs
# 99  222921424  MDEwOlJlcG9zaXRvcnkyMjI5MjE0MjQ=  dataV2-labs
#
#                        full_name  private  \
# 0         cmerticaru/dataV2-labs    False
# 1           aaronepv/dataV2-labs    False
# 2           Sanka101/dataV2-labs    False
# 3        Lucille-Art/dataV2-labs    False
# ...

# %% [markdown]
# #### 2. Count how many commit objects are contained in the array.

# %%
# your code here
commits.count()
# Out:
# id                   100
# node_id              100
# name                 100
# full_name            100
# private              100
#                     ...
# owner.type           100
# owner.site_admin     100
# permissions.admin    100
# permissions.push     100
# permissions.pull     100
# Length: 93, dtype: int64

# %% [markdown]
# ## Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain .scavengerhunt and they are scattered in different directories of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching the local files on your computer.
#
# #### 1. Find the secret files.

# %%
# your code here
url='https://api.github.com/repos/ironhack-datalabs/scavenger?page=1&per_page=100'

response1 = requests.get(url, headers ={'Authorization' : 'token 363abab909f45752e1ee3aaf446caf1834f63e7c' })
results1 = response1.json()
results1
# Out:
# {'id': 162375181,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=',
#  'name': 'scavenger',
#  'full_name': 'ironhack-datalabs/scavenger',
#  'private': False,
#  'owner': {'login': 'ironhack-datalabs',
#   'id': 44225188,
#   'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#   'avatar_url': 'https://avatars2.githubusercontent.com/u/44225188?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ironhack-datalabs',
#   'html_url': 'https://github.com/ironhack-datalabs',
#   'followers_url': 'https://api.github.com/users/ironhack-datalabs/followers',
#   'following_url': 'https://api.github.com/users/ironhack-datalabs/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/ironhack-datalabs/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/ironhack-datalabs/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/ironhack-datalabs/subscriptions',
# ...

# %% [markdown]
# #### 2.  Sort the filenames ascendingly.

# %%
# your code here
flattened_data1 = pd.json_normalize(results1)
df1=pd.DataFrame(flattened_data1)

df1
# Out:
#           id                           node_id       name  \
# 0  162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
#
#                      full_name  private  \
# 0  ironhack-datalabs/scavenger    False
#
#                                          html_url description   fork  \
# 0  https://github.com/ironhack-datalabs/scavenger        None  False
#
#                                                  url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
#
#                                            forks_url  ...  \
# 0  https://api.github.com/repos/ironhack-datalabs...  ...
#
#                           organization.following_url  \
# 0  https://api.github.com/users/ironhack-datalabs...
#
#                               organization.gists_url  \
# 0  https://api.github.com/users/ironhack-datalabs...
#
#                             organization.starred_url  \
# 0  https://api.github.com/users/ironhack-datalabs...
#
# ...

# %% [markdown]
# #### 3. Read the content of each secret files into an array of strings.
# Since the response is encoded, you will need to send the following information in the header of your request:
# ````python
# headers = {'Accept': 'application/vnd.github.v3.raw'}
# ````

# %%
# your code here

# %% [markdown]
# #### 4. Concatenate the strings in the array separating each two with a whitespace.

# %%
# your code here

# %% [markdown]
# #### 5. Print out the joke.

# %%
# your code here
